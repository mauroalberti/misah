# %%
from misah.geom2d import Point2D

# %%
p = Point2D(3, 4)

# %%
p2 = Point2D(7, 8)

# %%
p.distance(p2)
# Out:
# 5.656854249492381

# %%
p.x
# Out:
# 3.0

# %%
p.y
# Out:
# 4.0

# %%
p.x
# Out:
# 3.0

# %%
from misah.geom3d import Point3D

# %%
P1 = Point3D(1,2,3)

# %%
P2 = Point3D(3,4,5)

# %%
P1.distance(P2)
# Out:
# 3.4641016151377544

# %%
P1.x, P1.y, P1.z
# Out:
# (1.0, 2.0, 3.0)

# %%
from pygsf.geometries.shapes.space3d import Point3D as P3D

# %%
P1 = P3D(1,2,3)

# %%
P2 = P3D(3,4,5)

# %%
P1.distance(P2)
# Out:
# 3.4641016151377544
